# %%
import json
import folium
import googlemaps
import warnings
import pandas as pd

warnings.simplefilter( action = "ignore", category = FutureWarning)
stations = pd.read_csv('stations.csv', encoding = 'utf-8')

stations.sort_values(by = '가격', ascending = False).head(10)
# Out:
#      Unnamed: 0 Oil_store                          주소      가격 셀프     상표    구
# 325         325     서남주유소        서울 중구 통일로 30 (봉래동1가)  2132.0  N  SK에너지   중구
# 324         324     장충주유소      서울 중구 장충단로 202 (장충동1가)  2130.0  N  SK에너지   중구
# 124         124     양재주유소       서울 서초구 바우뫼로 178 (양재동)  2128.0  N  SK에너지  서초구
# 532         532   뉴서울(강남)        서울 강남구 언주로 716 (논현동)  2120.0  N  SK에너지  강남구
# 531         531     오천주유소       서울 강남구 봉은사로 503 (삼성동)  2107.0  N  SK에너지  강남구
# 313         313     재동주유소     서울특별시 종로구  율곡로 58 (경운동)  2106.0  N  SK에너지  종로구
# 285         285     청파주유소  서울특별시 용산구  청파로 311 (청파동1가)  2106.0  N  SK에너지  용산구
# 284         284    갈월동주유소   서울특별시 용산구  한강대로 322 (갈월동)  2106.0  N  SK에너지  용산구
# 283         283     강변주유소      서울특별시 용산구  원효로 9 (청암동)  2106.0  N  SK에너지  용산구
# 323         323     통일주유소       서울 중구 동호로 296 (장충동2가)  2106.0  N  SK에너지   중구

# %%
import numpy as np

gu_data = pd.pivot_table(stations, index=["구"], values=["가격"], aggfunc=np.mean)

gu_data.head()
# Out:
#               가격
# 구
# 강남구  1791.000000
# 강동구  1656.722222
# 강북구  1534.333333
# 강서구  1576.428571
# 관악구  1603.055556

# %%
geo_path = "../data/02. skorea_municipalities_geo_simple.json"
geo_str = json.load(open(geo_path, encoding='utf-8'))

map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles = 'Stamen Toner')
map.choropleth(geo_data= geo_str,
                data = gu_data['가격'],
                columns = [gu_data.index, gu_data['가격']],
                fill_color = 'PuRd',
                key_on = 'feature.id')

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
oil_price_top10 = stations.sort_values(by='가격', ascending=False).head(10)
oil_price_top10
# Out:
#      Unnamed: 0 Oil_store                          주소      가격 셀프     상표    구
# 325         325     서남주유소        서울 중구 통일로 30 (봉래동1가)  2132.0  N  SK에너지   중구
# 324         324     장충주유소      서울 중구 장충단로 202 (장충동1가)  2130.0  N  SK에너지   중구
# 124         124     양재주유소       서울 서초구 바우뫼로 178 (양재동)  2128.0  N  SK에너지  서초구
# 532         532   뉴서울(강남)        서울 강남구 언주로 716 (논현동)  2120.0  N  SK에너지  강남구
# 531         531     오천주유소       서울 강남구 봉은사로 503 (삼성동)  2107.0  N  SK에너지  강남구
# 313         313     재동주유소     서울특별시 종로구  율곡로 58 (경운동)  2106.0  N  SK에너지  종로구
# 285         285     청파주유소  서울특별시 용산구  청파로 311 (청파동1가)  2106.0  N  SK에너지  용산구
# 284         284    갈월동주유소   서울특별시 용산구  한강대로 322 (갈월동)  2106.0  N  SK에너지  용산구
# 283         283     강변주유소      서울특별시 용산구  원효로 9 (청암동)  2106.0  N  SK에너지  용산구
# 323         323     통일주유소       서울 중구 동호로 296 (장충동2가)  2106.0  N  SK에너지   중구

# %%
oil_price_bottom10 = stations.sort_values(by='가격', ascending=True).head(10)
oil_price_bottom10
# Out:
#      Unnamed: 0       Oil_store                          주소      가격 셀프  \
# 83           83        만남의광장주유소  서울 서초구 양재대로12길 73-71 (원지동)  1490.0  N
# 344         344       강서오곡셀프주유소     서울특별시 강서구 벌말로 254 (오곡동)  1497.0  Y
# 451         451         태릉솔밭주유소      서울특별시 노원구 노원로 49 (공릉동)  1497.0  Y
# 258         258          수유동주유소    서울특별시 강북구  도봉로 395 (수유동)  1498.0  Y
# 227         227         (주)강서오일       서울 영등포구 도신로 151 (도림동)  1499.0  N
# 225         225           도림주유소       서울 영등포구 도림로 343 (도림동)  1499.0  Y
# 226         226  (주)대청에너지 대청주유소      서울 영등포구 가마산로 328 (대림동)  1499.0  N
# 415         415          풀페이주유소      서울특별시 구로구 경인로 41 (온수동)  1499.0  N
# 326         326         신일셀프주유소         서울 중랑구 상봉로 58 (망우동)  1499.0  Y
# 40           40           서경주유소        서울 동작구 대림로 46 (신대방동)  1499.0  N
#
#          상표     구
# 83   알뜰(ex)   서초구
# 344   SK에너지   강서구
# 451   S-OIL   노원구
# 258   GS칼텍스   강북구
# 227  현대오일뱅크  영등포구
# 225   알뜰주유소  영등포구
# 226   GS칼텍스  영등포구
# 415   SK에너지   구로구
# 326   SK에너지   중랑구
# 40   현대오일뱅크   동작구

# %%
gmap_key = "AIzaSyAeshgvtBkeIneQavQaS_TawK_OOK-F7FM"
gmaps = googlemaps.Client(key= gmap_key)

tmp_map = gmaps.geocode('서울 서초구 양재대로12길 73-71')
tmp_map
# Out:
# [{'address_components': [{'long_name': '73-71',
#     'short_name': '73-71',
#     'types': ['premise']},
#    {'long_name': 'Yangjae-daero 12-gil',
#     'short_name': 'Yangjae-daero 12-gil',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': 'Yangjae 2(i)-dong',
#     'short_name': 'Yangjae 2(i)-dong',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': 'Seocho-gu',
#     'short_name': 'Seocho-gu',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Seoul',
#     'short_name': 'Seoul',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'South Korea',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '137-132',
#     'short_name': '137-132',
#     'types': ['postal_code']}],
#   'formatted_address': '73-71 Yangjae-daero 12-gil, Yangjae 2(i)-dong, Seocho-gu, Seoul, South Korea',
#   'geometry': {'location': {'lat': 37.4599063, 'lng': 127.0420601},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.4612552802915,
#      'lng': 127.0434090802915},
#     'southwest': {'lat': 37.4585573197085, 'lng': 127.0407111197085}}},
#   'place_id': 'ChIJabDNgiqnfDURQtLxzMo31Xw',
#   'plus_code': {'compound_code': 'F25R+XR Seoul, South Korea',
#    'global_code': '8Q99F25R+XR'},
#   'types': ['street_address']}]

# %%
lat = []
lng = []

for n in tqdm_notebook(oil_price_top10.index):
    try:
        tmp_add = str(oil_price_top10['주소'][n]).split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)

        # tmp_loc = tmp_map[0]['geometry']
        lat.append(tmp_map[0]['geometry']['location']['lat'])
        lng.append(tmp_map[0]['geometry']['location']['lng'])
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")

oil_price_top10['lat'] = lat
oil_price_top10['lng'] = lng
oil_price_top10
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
#      Unnamed: 0 Oil_store                          주소      가격 셀프     상표    구  \
# 325         325     서남주유소        서울 중구 통일로 30 (봉래동1가)  2132.0  N  SK에너지   중구
# 324         324     장충주유소      서울 중구 장충단로 202 (장충동1가)  2130.0  N  SK에너지   중구
# 124         124     양재주유소       서울 서초구 바우뫼로 178 (양재동)  2128.0  N  SK에너지  서초구
# 532         532   뉴서울(강남)        서울 강남구 언주로 716 (논현동)  2120.0  N  SK에너지  강남구
# 531         531     오천주유소       서울 강남구 봉은사로 503 (삼성동)  2107.0  N  SK에너지  강남구
# 313         313     재동주유소     서울특별시 종로구  율곡로 58 (경운동)  2106.0  N  SK에너지  종로구
# 285         285     청파주유소  서울특별시 용산구  청파로 311 (청파동1가)  2106.0  N  SK에너지  용산구
# 284         284    갈월동주유소   서울특별시 용산구  한강대로 322 (갈월동)  2106.0  N  SK에너지  용산구
# 283         283     강변주유소      서울특별시 용산구  원효로 9 (청암동)  2106.0  N  SK에너지  용산구
# 323         323     통일주유소       서울 중구 동호로 296 (장충동2가)  2106.0  N  SK에너지   중구
#
#            lat         lng
# 325  37.558348  126.972090
# 324  37.562719  127.007010
# 124  37.478071  127.039610
# 532  37.517636  127.035756
# 531  37.513458  127.053786
# 313  37.576388  126.985851
# 285  37.547451  126.969904
# 284  37.546955  126.972218
# 283  37.534910  126.945869
# 323  37.560714  127.003177

# %%
from tqdm import tqdm_notebook

lat = []
lng = []

for n in tqdm_notebook(oil_price_bottom10.index):
    try:
        tmp_add = str(oil_price_bottom10['주소'][n]).split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)

        # tmp_loc = tmp_map[0]['geometry']
        lat.append(tmp_map[0]['geometry']['location']['lat'])
        lng.append(tmp_map[0]['geometry']['location']['lng'])
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")

oil_price_bottom10['lat'] = lat
oil_price_bottom10['lng'] = lng
oil_price_bottom10
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
#      Unnamed: 0       Oil_store                          주소      가격 셀프  \
# 83           83        만남의광장주유소  서울 서초구 양재대로12길 73-71 (원지동)  1490.0  N
# 344         344       강서오곡셀프주유소     서울특별시 강서구 벌말로 254 (오곡동)  1497.0  Y
# 451         451         태릉솔밭주유소      서울특별시 노원구 노원로 49 (공릉동)  1497.0  Y
# 258         258          수유동주유소    서울특별시 강북구  도봉로 395 (수유동)  1498.0  Y
# 227         227         (주)강서오일       서울 영등포구 도신로 151 (도림동)  1499.0  N
# 225         225           도림주유소       서울 영등포구 도림로 343 (도림동)  1499.0  Y
# 226         226  (주)대청에너지 대청주유소      서울 영등포구 가마산로 328 (대림동)  1499.0  N
# 415         415          풀페이주유소      서울특별시 구로구 경인로 41 (온수동)  1499.0  N
# 326         326         신일셀프주유소         서울 중랑구 상봉로 58 (망우동)  1499.0  Y
# 40           40           서경주유소        서울 동작구 대림로 46 (신대방동)  1499.0  N
#
#          상표     구        lat         lng
# 83   알뜰(ex)   서초구  37.459906  127.042060
# 344   SK에너지   강서구  37.555284  126.768567
# 451   S-OIL   노원구  37.625918  127.085533
# 258   GS칼텍스   강북구  37.642140  127.029568
# 227  현대오일뱅크  영등포구  37.509969  126.908231
# 225   알뜰주유소  영등포구  37.507656  126.900191
# 226   GS칼텍스  영등포구  37.498556  126.895791
# 415   SK에너지   구로구  37.491009  126.826675
# 326   SK에너지   중랑구  37.590907  127.093834
# 40   현대오일뱅크   동작구  37.487947  126.908240

# %%
map = folium.Map(location=[37.5502, 126.975], zoom_start=10.5)

for n in oil_price_top10.index:
    if pd.notnull(oil_price_top10['lat'][n]):
        folium.CircleMarker([oil_price_top10['lat'][n], oil_price_top10['lng'][n]],
                            radius=15, color = '#CD3181' , fill_color = '#CD3181').add_to(map)

for n in oil_price_bottom10.index:
    if pd.notnull(oil_price_bottom10['lat'][n]):
        folium.CircleMarker([oil_price_bottom10['lat'][n], oil_price_bottom10['lng'][n]],
                            radius=15, color = '#3186cc', fill_color = '#3186cc').add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

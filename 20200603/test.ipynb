# %%
import numpy as np
import pandas as pd

data = pd.read_csv("ign_game_reviews.csv")
data.head()
data.tail()
data.iloc[0:5,:]
data.iloc[:,0:3]
data.iloc[[1,9],:]

df = data.iloc[:,1:]
df.head()
df.loc[:5,'score']

df.columns
df.loc[:5,['score','release_year']]
type(df["score"])
df["score"].sum()
df["score"].mean() #특정 컬럼에 대한 평균
df.mean() #전체 컬럼에 대한 평균
df.mean(axis=0) #열 기준 평균 (위의 것과 같음)
df.mean(axis=1) #행 기준 평균
df.count()
df.describe()
df.corr() #상관관계 관계가 높을수록 1에 가깝다.
df["score"] /2
filter = df["score"] > 7
filter
df2 = df[filter] #안됨ㅜ

df["platform"]
filter2 = (df["score"] > 7) & (df["platform"] == "Xbox 360")
df3 = df[filter2]
df3
df3["score"].plot(kind="hist")

# %%
filter3 = df["platform"] == "Xbox 360"
df[filter3]["score"].plot(kind="hist")
#df[df["platform"] == "Xbox 360"]
